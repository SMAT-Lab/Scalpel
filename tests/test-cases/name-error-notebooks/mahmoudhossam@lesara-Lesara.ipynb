# %%
import pandas as pd

# %%
import dill

# %%
import numpy

# %%
# %matplotlib inline

# %%
df = pd.read_csv("orders.csv", parse_dates=["created_at_date"])

# %%
df.head()
# Out:
#                         customer_id  order_id  order_item_id  num_items  \
# 0  37d67f5feef4cb754056a54841e43ad9   4662083     21257304.0        1.0
# 1  d0d7a76fea3729a9381d39aca78b52d3   4655291     21224156.0        1.0
# 2  450e1c2cbd21687780153995f1be0c23   4661361     21253627.0        1.0
# 3  1b9131d69fb9745f0c22e22c6d55437f   4656415     21229235.0        1.0
# 4  03c9fd0e00e2cef5d72d0af8e869aabe   4658541     21239714.0        1.0
#
#    revenue created_at_date
# 0    24.79      2017-09-01
# 1    22.68      2017-09-01
# 2    10.07      2017-09-01
# 3     7.37      2017-09-01
# 4    16.66      2017-09-01

# %%
df.keys()
# Out:
# Index(['customer_id', 'order_id', 'order_item_id', 'num_items', 'revenue',
#        'created_at_date'],
#       dtype='object')

# %%
max_revenue = df[['customer_id', 'revenue']].groupby('customer_id', as_index=True).max()['revenue']

# %%
df[['customer_id', 'order_id']].groupby(['customer_id']).order_id.nunique().to_frame()
# Out:
#                                   order_id
# customer_id
# 000011265b8a3727c4cc77b494134aca         1
# 000079318ce4bdc1897a9c711e107b55         1
# 0000e349e3d5eb96a2dc1939beebf9e4         1
# 0001159afe8b9309aeb95fa17886d688         1
# 000146a1e6decca6773a52afd2ed0255         2
# 0001aa41356a707949e8a715947ff85c         1
# 0001b3166c1bcb11f331e6676f7863a9         1
# 0001cf68347245f00fe71fd9d677e9df         1
# 00022da3f8257cbda32247d4e02c4b6d         1
# 0002ec88abff6d01da3b9db674cd8868         1
# 00031d78053496b61d5ea754f06a3517         1
# 00038936c3f4ba79ed4987dc58b24379         1
# 00039ffee8cb571b6bdc2abeea7d295b         1
# 0003e28112462c2fdea1a32b1012f040         1
# 00041ce3bf6938f7e0c89f684a65649f         1
# 000470c14e4d8c4174a55efb438e256a         1
# 0004cc28024393ee5952f2d1f11f9a21         1
# 000520f542320f2cc48ffdf5e9a36470         1
# 000588a176b46625e251e0d55be87d66         1
# 0005f614f74480bf24dba66c3a4bab22         2
# 000625f22b7c3ef072cc3b846d78161b         1
# 000658043a603f0bb4ac26755c2bdfc6         1
# 0006f5873b7a21c6b84984ca53c83ce9         1
# 000706614fd5f9235d33eb8e618136c1         1
# 00070ecc66d644491cad66f287472d35         1
# 00079dcefe445bfa23d4a7ec82eb8b4c         1
# 0007d44c1d2f32ad5914803f8c901e38         1
# 0007e6a75df7dd3dfe5e53bd17bd2994         1
# 00080a57440bd81e0ee83d2316884749         2
# 0008513072f3ad00d345348b33ed17f9         1
# ...                                    ...
# fff6bb8f0d80dfae7417e78389225b5c         2
# fff6df958e0db6881b3dc9f26b67b979         1
# fff791886ca6ecaca3c77dab182ea849         1
# fff79c9370f9a4711cf431295ab29b39         1
# fff83af7071d0e165731cc661686b133         1
# fff8b56ea8e7fb377bdadfc19c222d7b         1
# fff8d29bbcd9861ab26e75ee57e3f8de         1
# fff98f46370eb3875b189aaf71aa7086         1
# fff9c093783d0a9c236d31da37a8286b         1
# fffae8c69e27a46f67f3e12daddafb73         1
# fffb4cef5985f954652c36e669f27169         1
# fffb5cf94c847c463becfca362130698         1
# fffbb71c5e558be594e2749be493b8cc         1
# fffc016e5268e38abbded31d2d64abe9         1
# fffc120d8fa3de072a64fd21e4a49510         1
# fffc3221023a7139f178c833ea86f34f         2
# fffc5908ae22ee03cb6ffe814adefe37         1
# fffc639fb0fc159a85b0e61694dd1e52         1
# fffc9a4bdaeaf2a78d87dc67644e9d32         1
# fffca198c736e2c8652cd5cb791585e6         1
# fffd02692000dd392ffa6218a946dc1b         2
# fffd7075b2a9034bf02202bf6cb5c63e         1
# fffdbdaab8e238dce36e3663bec437d5         1
# fffe543ca6c58da27cebfc6bb70781dc         1
# fffe9636beeecbc5d14ac9fa7496cc6e         1
# fffeb0696cdfba8e4257c5f0debc0f9a         1
# fffeb5a50fd119d596b5de4262670751         1
# ffff1e6dda9bbc57eb9b34a62be39fac         1
# ffff1f457de00c3514de1b589517f9f9         1
# ffffc596e5d3460994602e7d331be676         1
#
# [216600 rows x 1 columns]

# %%
max_items = df[['customer_id', 'num_items']].groupby('customer_id', as_index=True).max()['num_items']

# %%
total_revenue = df[['customer_id', 'revenue']].groupby('customer_id', as_index=True).sum()['revenue']

# %%
days_since_last_order = pd.Timestamp.strptime('2017-10-17', '%Y-%m-%d') - df[['customer_id', 'created_at_date']].groupby('customer_id', as_index=True).max()['created_at_date']

# %%
result = pd.DataFrame({'Max revenue': max_revenue, 'Order count': order_count, 'Max items': max_items, 'Total revenue': total_revenue, 'Days since last order': days_since_last_order})

# %%
model = dill.load(open("model.dill", 'rb'))

# %%
array = numpy.array([[2, 5, 6, 7, 9, 10], [3, 6, 7, 8, 11, 12]])

# %%
model.predict(array)
# Out:
# array([39, 47])

# %%
df['revenue'].plot()

# %%
result
# Out:
#                                  Days since last order  Max items  \
# customer_id
# 000011265b8a3727c4cc77b494134aca               18 days        1.0
# 000079318ce4bdc1897a9c711e107b55                2 days        1.0
# 0000e349e3d5eb96a2dc1939beebf9e4                4 days        1.0
# 0001159afe8b9309aeb95fa17886d688               26 days        1.0
# 000146a1e6decca6773a52afd2ed0255               20 days        1.0
# 0001aa41356a707949e8a715947ff85c               39 days        1.0
# 0001b3166c1bcb11f331e6676f7863a9               11 days        1.0
# 0001cf68347245f00fe71fd9d677e9df                6 days        1.0
# 00022da3f8257cbda32247d4e02c4b6d               18 days        1.0
# 0002ec88abff6d01da3b9db674cd8868                3 days        1.0
# fff8d29bbcd9861ab26e75ee57e3f8de    16.520000            1      16.520000
# fff98f46370eb3875b189aaf71aa7086     8.260000            2      14.030000
# fff9c093783d0a9c236d31da37a8286b    11.660000            1      11.660000
# fffae8c69e27a46f67f3e12daddafb73    16.540880            1      16.540880
# fffb4cef5985f954652c36e669f27169    16.800000            1      16.800000
# fffb5cf94c847c463becfca362130698    25.200000            7      99.940000
# fffbb71c5e558be594e2749be493b8cc    14.750000            1      14.750000
# fffc016e5268e38abbded31d2d64abe9    50.410000            5     152.060000
# fffc120d8fa3de072a64fd21e4a49510    24.580000            1      24.580000
# fffc3221023a7139f178c833ea86f34f    24.580000            6      97.490000
# fffc5908ae22ee03cb6ffe814adefe37    24.790000            1      24.790000
# fffc639fb0fc159a85b0e61694dd1e52    14.280000            5      59.620000
# fffc9a4bdaeaf2a78d87dc67644e9d32    29.288080            4      79.388320
# fffca198c736e2c8652cd5cb791585e6     8.400000            6      35.250000
# fffd02692000dd392ffa6218a946dc1b    32.760000            3      56.270000
# fffd7075b2a9034bf02202bf6cb5c63e    20.480000            1      20.480000
# fffdbdaab8e238dce36e3663bec437d5    29.410000            8     168.000000
# fffe543ca6c58da27cebfc6bb70781dc    29.400000            2      54.610000
# fffe9636beeecbc5d14ac9fa7496cc6e    24.790000            2      49.570000
# fffeb0696cdfba8e4257c5f0debc0f9a    21.840000            3      52.920000
# fffeb5a50fd119d596b5de4262670751    16.800000            4      67.190000
# ffff1e6dda9bbc57eb9b34a62be39fac    22.650000            2      26.850000
# ffff1f457de00c3514de1b589517f9f9    24.790000            1      24.790000
# ffffc596e5d3460994602e7d331be676    49.160000            1      49.160000
#
# [216600 rows x 5 columns]

# %%
customers_orders = df.groupby(['customer_id', 'order_id'])

# %%
def max_items():
    return df.groupby(['customer_id', 'order_id'])['customer_id', 'order_id', 'num_items'].sum().groupby(['customer_id']).max()

# %%
df.head()
# Out:
#                         customer_id  order_id  order_item_id  num_items  \
# 0  37d67f5feef4cb754056a54841e43ad9   4662083     21257304.0        1.0
# 1  d0d7a76fea3729a9381d39aca78b52d3   4655291     21224156.0        1.0
# 2  450e1c2cbd21687780153995f1be0c23   4661361     21253627.0        1.0
# 3  1b9131d69fb9745f0c22e22c6d55437f   4656415     21229235.0        1.0
# 4  03c9fd0e00e2cef5d72d0af8e869aabe   4658541     21239714.0        1.0
#
#    revenue created_at_date
# 0    24.79      2017-09-01
# 1    22.68      2017-09-01
# 2    10.07      2017-09-01
# 3     7.37      2017-09-01
# 4    16.66      2017-09-01

# %%
lol = df[['customer_id', 'created_at_date']].groupby('customer_id').max()['created_at_date'].subtract(pd.Timestamp(datetime(2017, 10, 17))).abs().to_frame()

# %%
lol.dtypes
# Out:
# created_at_date    timedelta64[ns]
# dtype: object
